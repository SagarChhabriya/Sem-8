# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# import pymango as mdb
import mysql.connector as dbms 
# pip install resources staty

# %%
class a:
    x = 0
    y = 0

    def abc(self) -> None:
        print("abc message")

    def __init__(self, x, y) -> None:
        self.x = x
        self.y = y

    def add(self):
        print(self.x + self.y)

# %%
obj = a(10,10)

obj.add()
# Out:
# 20

# %%
# Parent class
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name} makes a sound.")

# Child class inherits from Animal
class Dog(Animal):
    def speak(self):
        print(f"{self.name} says Woof!")

class Cat(Animal):
    def speak(self):
        print(f"{self.name} says Meow!")

# Example usage
dog = Dog("Buddy")
cat = Cat("Whiskers")

dog.speak()  # Output: Buddy says Woof!
cat.speak()  # Output: Whiskers says Meow!
# Out:
# Buddy says Woof!
# Whiskers says Meow!

# %%
conn = dbms.connect(
    host="localhost",
    user="root",
    password="root",
    database="mydatabase"
)

cursor = conn.cursor()
cursor.execute("SELECT * FROM customers")
print(cursor.fetchall())
# Out:
# [('Sagar', 'Kandhkot', 1), ('Johnna', '123 Main St', 2), ('Jane Smith', '456 Elm Ave', 3), ('A', 'aaa', 5), ('B', 'bbb', 6), ('C', 'ccc', 7), ('D', 'ddd', 8), ('E', 'eee', 9), ('F', 'fff', 10), ('G', 'ggg', 11), ('H', 'hhh', 12), ('I', 'iii', 13), ('J', 'jjj', 14)]

# %% [markdown]
# mongodb
# - use table_name
# - pip install pymongo

# %%
from pymongo import MongoClient

# Replace the connection string with your MongoDB URI
client = MongoClient("mongodb://localhost:27017/")  # Local MongoDB
# OR for cloud (MongoDB Atlas)
# client = MongoClient("mongodb+srv://username:password@cluster0.mongodb.net/mydatabase?retryWrites=true&w=majority")

# Access a database
db = client["mydatabase"]

# Access a collection (like a table)
collection = db["mycollection"]

# Example: Insert a document
doc = {"name": "Alice", "age": 25}
collection.insert_one(doc)

# Example: Find documents
for document in collection.find():
    print(document)
